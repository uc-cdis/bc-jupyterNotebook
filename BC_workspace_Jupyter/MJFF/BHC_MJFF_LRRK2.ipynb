# %% [markdown]
# # LRRK2 Summary Statistics - MJFF Data Commons Demo

# %%
# %matplotlib inline
import bhc_analysis_functions as bc
bc.add_keys('credentials.json')

# %% [markdown]
# ## PD Status & LRRK2 Mutation Status

# %% [markdown]
# #### Frequency table to describe PD Status

# %%
bc.get_frequency_table("mjff-LRRK2", "diagnosis", "PD")
# Out:
# col_0  Frequency  Percentage  Cumulative Frequency  Cumulative Percentage
# PD
# No          1230       43.16                  1230                  43.16
# Yes         1620       56.84                  2850                 100.00

# %% [markdown]
# #### Frequency table for LRRK2 Mutation Status

# %%
bc.get_frequency_table("mjff-LRRK2", "biomarker", "LRRK2")
# Out:
# col_0  Frequency  Percentage  Cumulative Frequency  Cumulative Percentage
# LRRK2
# No          1305       45.79                  1305                  45.79
# Yes         1545       54.21                  2850                 100.00

# %% [markdown]
# #### Frequency table of PD by LRRK2

# %%
bc.get_frequency_cross_table("mjff-LRRK2", ["diagnoses", "biomarkers"], ["PD", "LRRK2"])
# Out:
# col_0      Frequency  Percentage
# PD  LRRK2
# No  No           508       17.82
#     Yes          722       25.33
# Yes No           797       27.96
#     Yes          823       28.88

# %% [markdown]
# ## Subjects with a Subject-Level Mutation

# %%
bc.get_frequency_mutation_table("mjff-LRRK2", "LRRK2")
# Out:
# col_0   PD (N = 823)  PD (%)  HC (N = 722)  HC (%)  Total (N = 1545)  \
# 0
# G2019S           523   63.55           344   47.65               867
# G238R            202   24.54           226   31.30               428
# R1628P            59    7.17            95   13.16               154
# R1441G            28    3.40            39    5.40                67
# Other              6    0.73             2    0.28                 8
# I2020T             3    0.36             0    0.00                 3
# N1437H             2    0.24             4    0.55                 6
# C228S              1    0.12             2    0.28                 3
# R1325Q             1    0.12             0    0.00                 1
# R1441C             1    0.12             3    0.42                 4
#
# col_0   Total (%)
# 0
# G2019S      56.12
# G238R       27.70
# R1628P       9.97
# R1441G       4.34
# Other        0.52
# I2020T       0.19
# N1437H       0.39
# C228S        0.19
# R1325Q       0.06
# R1441C       0.26

# %% [markdown]
# ## Demographics for all subjects

# %% [markdown]
# #### Analysis Variable: Age

# %%
bc.get_summary_statistics("mjff-LRRK2", "diagnosis", "Diagnosis Age")
# Out:
#                             count       mean        std   min   25%   50%  \
# Diagnosis Age (mjff-LRRK2)  903.0  60.222591  11.354315  24.0  54.0  61.0
#
#                              75%   max
# Diagnosis Age (mjff-LRRK2)  68.0  88.0

# %% [markdown]
# #### Analysis Variable: Gender

# %%
bc.get_frequency_table("mjff-LRRK2", "demographic", "gender")
# Out:
# col_0   Frequency  Percentage  Cumulative Frequency  Cumulative Percentage
# gender
# Female       1441       50.56                  1441                  50.56
# Male         1409       49.44                  2850                 100.00

# %% [markdown]
# #### Analysis Variable: Race

# %%
bc.get_frequency_table("mjff-LRRK2", "demographic", "racetxt")
# Out:
# col_0                  Frequency  Percentage  Cumulative Frequency  \
# racetxt
# African                        1        0.04                     1
# Arab-Berber                  584       20.49                   585
# Arabic (North Africa)          1        0.04                   586
# Black, Filipino                1        0.04                   587
# Caucasian                   1672       58.67                  2259
# Chinese                      400       14.04                  2659
# Hispanic                       1        0.04                  2660
# Korean                         1        0.04                  2661
# Latin American                 1        0.04                  2662
# North African                  2        0.07                  2664
# North African Arab             1        0.04                  2665
# Other                        181        6.35                  2846
# Portugal White                 1        0.04                  2847
# South Asian                    1        0.04                  2848
# Southeast Asian                1        0.04                  2849
# West Asian                     1        0.04                  2850
#
# col_0                  Cumulative Percentage
# racetxt
# African                                 0.04
# Arab-Berber                            20.53
# Arabic (North Africa)                  20.56
# Black, Filipino                        20.60
# Caucasian                              79.26
# Chinese                                93.30
# Hispanic                               93.33
# Korean                                 93.37
# Latin American                         93.40
# North African                          93.47
# North African Arab                     93.51
# Other                                  99.86
# Portugal White                         99.89
# South Asian                            99.93
# Southeast Asian                        99.96
# West Asian                            100.00

# %% [markdown]
# #### Analysis Variable: Education

# %%
bc.get_frequency_table("mjff-LRRK2", "demographic", "highest_education")
# Out:
# col_0                                               Frequency  Percentage  \
# highest_education
# College/University Or Equivalent (14-16 Years)            594       29.80
# Elementary/Middle School Or Equivalent (<=8 Years)        379       19.02
# High School Or Equivalent (9-13 Years)                    419       21.02
# Post College/University (>16 Years)                       601       30.16
#
# col_0                                               Cumulative Frequency  \
# highest_education
# College/University Or Equivalent (14-16 Years)                       594
# Elementary/Middle School Or Equivalent (<=8 Years)                   973
# High School Or Equivalent (9-13 Years)                              1392
# Post College/University (>16 Years)                                 1993
#
# col_0                                               Cumulative Percentage
# highest_education
# College/University Or Equivalent (14-16 Years)                      29.80
# Elementary/Middle School Or Equivalent (<=8 Years)                  48.82
# High School Or Equivalent (9-13 Years)                              69.84
# Post College/University (>16 Years)                                100.00

# %% [markdown]
# ## LED in PD Subjects

# %% [markdown]
# #### Analysis Variable: LED

# %%
bc.get_summary_statistics("mjff-LRRK2", "medication", "LED", "PD")
# Out:
#                    count        mean         std  min   25%    50%    75%  \
# LED (mjff-LRRK2)  1091.0  450.574297  458.241789  0.0  55.0  375.0  650.0
#
#                      max
# LED (mjff-LRRK2)  3400.0

# %% [markdown]
# #### Analysis Variable: Duration of Disease (Years)

# %%
bc.get_summary_statistics("mjff-LRRK2", "diagnosis", "Disease Duration")
# Out:
#                                 count      mean       std  min  25%  50%  \
# Disease Duration (mjff-LRRK2)  1501.0  7.625583  6.164067  0.0  3.0  6.0
#
#                                 75%   max
# Disease Duration (mjff-LRRK2)  11.0  44.0

# %% [markdown]
# ## Assessments for Subjects with Confirmed PD and LRRK2 Status

# %%
bc.get_assessment_statistics("mjff-LRRK2")
# Out:
#                                     count       mean        std   min   25%  \
# UPSIT                              1138.0  27.629174   8.517637   2.0  22.0
# UPDRS Total On                      149.0  19.959732  20.642183   0.0   3.0
# UPDRS Total Off                    1496.0  22.625334  21.722932   0.0   3.0
# UPDRS 3                            1764.0  14.354025  14.216604   0.0   2.0
# UPDRS 2 Overall                     151.0   5.569536   7.057393   0.0   0.0
# UPDRS 2 On                         1591.0   6.890006   7.418223   0.0   0.0
# UPDRS 2 Off                          76.0   9.631579   8.864675   0.0   3.0
# UPDRS 1 Overall                     186.0   1.564516   1.958662   0.0   0.0
# UPDRS 1 On                         1612.0   1.545285   1.868703   0.0   0.0
# SCOPA-AUT                          1647.0  11.664845   9.322590   0.0   4.0
# REM Sleep Disorder                  610.0   2.957377   2.713734   0.0   1.0
# Modified Schwab & England Overall   744.0  82.997312  21.177199  10.0  77.5
# Modified Schwab & England On       1266.0  90.908373  15.945941  10.0  90.0
# Modified Schwab & England Off        23.0  76.521739  21.021352  20.0  75.0
# MoCA                               2005.0  24.920698   4.257223   3.0  23.0
# MDS-UPDRS Total On                  393.0  69.312977  33.260893   4.0  45.0
# MDS-UPDRS Total Off                 119.0  21.689076  32.399453   0.0   4.0
# MDS-UPDRS 4                         407.0   4.501229   4.287612   0.0   0.0
# MDS-UPDRS 3 On                      383.0  40.368146  20.253052   3.0  25.0
# MDS-UPDRS 3 Off                     115.0  12.165217  19.733723   0.0   1.0
# MDS-UPDRS 2                         513.0  14.463938  10.881606   0.0   6.0
# MDS-UPDRS 1                         510.0  10.864706   7.637626   0.0   5.0
# GDS                                2342.0   4.405636   3.827587   0.0   1.0
#
#                                      50%     75%    max
# UPSIT                               30.0   34.75   40.0
# UPDRS Total On                      12.0   32.00  113.0
# UPDRS Total Off                     19.0   35.00  149.0
# UPDRS 3                             11.0   23.00   97.0
# UPDRS 2 Overall                      3.0    8.50   36.0
# UPDRS 2 On                           5.0   11.00   40.0
# UPDRS 2 Off                          7.0   15.00   37.0
# UPDRS 1 Overall                      1.0    2.00   12.0
# UPDRS 1 On                           1.0    2.00   15.0
# SCOPA-AUT                            9.0   17.00   57.0
# REM Sleep Disorder                   2.0    4.00   13.0
# Modified Schwab & England Overall   90.0  100.00  100.0
# Modified Schwab & England On       100.0  100.00  100.0
# Modified Schwab & England Off       80.0   90.00  100.0
# MoCA                                26.0   28.00   30.0
# MDS-UPDRS Total On                  66.0   86.00  192.0
# MDS-UPDRS Total Off                  7.0   21.50  176.0
# MDS-UPDRS 4                          4.0    7.00   22.0
# MDS-UPDRS 3 On                      38.0   52.00  108.0
# MDS-UPDRS 3 Off                      3.0   13.00   99.0
# MDS-UPDRS 2                         14.0   20.00   49.0
# MDS-UPDRS 1                         10.0   16.00   41.0
# GDS                                  3.5    7.00   15.0
